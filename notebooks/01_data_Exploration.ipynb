# %%
df.to_csv("/Users/winifred/Documents/NHS-Wait-Time-Analysis/Data/Cleaned/nhs_ae_cleaned.csv", index=False)

# %%
df.head()
# Out:
#   Provider_Code                        Region  \
# 0           RC9  NHS England East Of England
# 1           RGT  NHS England East Of England
# 2           RWH  NHS England East Of England
# 3           RDE  NHS England East Of England
# 4           RY4  NHS England East Of England
#
#                                           Trust Name Type 1 A&E Attendances  \
# 0        Bedfordshire Hospitals NHS Foundation Trust                  17026
# 1  Cambridge University Hospitals NHS Foundation ...                  11282
# 2             East And North Hertfordshire NHS Trust                   9225
# 3  East Suffolk And North Essex NHS Foundation Trust                  13117
# 4                  Hertfordshire Community NHS Trust                      0
#
#   Type 2 A&E Attendances Type 3 A&E Attendances Total A&E Attendances  \
# 0                      0                   9599                 26625
# 1                      0                   6535                 17817
# ...

# %%
# Drop first row of NaNs
df = df.drop(index=0).reset_index(drop=True)

# Drop the 'Comments' column
df = df.drop(columns=['Comments'])

# %%
df.head()
# Out:
#   Provider_Code                        Region  \
# 0           NaN                           NaN
# 1           RC9  NHS England East Of England
# 2           RGT  NHS England East Of England
# 3           RWH  NHS England East Of England
# 4           RDE  NHS England East Of England
#
#                                           Trust Name Type 1 A&E Attendances  \
# 0                                                NaN                    NaN
# 1        Bedfordshire Hospitals NHS Foundation Trust                  17026
# 2  Cambridge University Hospitals NHS Foundation ...                  11282
# 3             East And North Hertfordshire NHS Trust                   9225
# 4  East Suffolk And North Essex NHS Foundation Trust                  13117
#
#   Type 2 A&E Attendances Type 3 A&E Attendances Total A&E Attendances  \
# 0                    NaN                    NaN                   NaN
# 1                      0                   9599                 26625
# ...

# %%
df.rename(columns={
    'Unnamed: 1': 'Provider_Code',
    'Unnamed: 2': 'Region',
    'Unnamed: 3': 'Trust Name',
    'A&E attendances': 'Type 1 A&E Attendances',
    'Unnamed: 5': 'Type 2 A&E Attendances',
    'Unnamed: 6': 'Type 3 A&E Attendances',
    'Unnamed: 7': 'Total A&E Attendances',
    'A&E attendances less than 4 hours from arrival to admission, transfer or discharge': 'Seen <4 Hours',
    'Unnamed: 9': 'Type 2 Seen <4 Hours',
    'Unnamed: 10': 'Type 3 Seen <4 Hours',
    'Unnamed: 11': '>4hrs from Arrival',
    'Unnamed: 13': 'Type 1 Admissions',
    'Unnamed: 14': 'Type 2 Admissions',
    'Unnamed: 15': 'Type 3 Admissions',
    'Percentage of attendances within 4 hours': '% Seen <4 Hours',
    'Unnamed: 17': 'Admissions >4hrs from Decision',
    'Unnamed: 18': 'Admissions >12hrs from Decision',
    'Unnamed: 19': 'Other Emergency Admissions',
    'Emergency Admissions': 'Total Emergency Admissions',
    'Unnamed: 21': 'Elective Admissions',
    'Unnamed: 22': 'Cancelled Elective Admissions',
    'Unnamed: 23': 'Delayed Transfers',
    'Unnamed: 24': 'Bed Days',
    'Unnamed: 25': 'Staff Shortages',
    'Unnamed: 26': 'Covid Admissions',
    'Unnamed: 27': 'Notes',
    'Unnamed: 28': 'Comments'
}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 28 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   Unnamed: 1                                                                             198 non-null    object
#  1   Unnamed: 2                                                                             198 non-null    object
#  2   Unnamed: 3                                                                             198 non-null    object
#  3   A&E attendances                                                                        198 non-null    object
#  4   Unnamed: 5                                                                             198 non-null    object
# ...

# %%
# Preview the cleaned data
df.head()
# Out:
#   Unnamed: 1                    Unnamed: 2  \
# 0        NaN                           NaN
# 1        RC9  NHS England East Of England
# 2        RGT  NHS England East Of England
# 3        RWH  NHS England East Of England
# 4        RDE  NHS England East Of England
#
#                                           Unnamed: 3 A&E attendances  \
# 0                                                NaN             NaN
# 1        Bedfordshire Hospitals NHS Foundation Trust           17026
# 2  Cambridge University Hospitals NHS Foundation ...           11282
# 3             East And North Hertfordshire NHS Trust            9225
# 4  East Suffolk And North Essex NHS Foundation Trust           13117
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN
# 1          0       9599      26625
# 2          0       6535      17817
# 3          0       8769      17994
# 4          0      15563      28680
#
# ...

# %%
# Reset the index
df.reset_index(drop=True, inplace=True)

# %%
# Drop columns that are entirely empty 
df = df.dropna(axis=1, how= 'all')

# %%
# Drop the first row

df = df.iloc[1:]

# %%
df = pd.read_excel(file_path, sheet_name='Provider Level Data', skiprows=14)

df.head()

# %%
df = df.dropna(axis=0, how='all')  # drop rows that are all NaN

# %%
df = df.dropna(axis=1, how='all')  # drop columns that are all NaN

# %%
df = pd.read_excel(file_path, sheet_name='Provider Level Data', skiprows=15, header=1)

df.head()
# Out:
#    Unnamed: 0    -                           -.1  \
# 0         NaN  NaN                           NaN
# 1         NaN  RC9  NHS England East Of England
# 2         NaN  RGT  NHS England East Of England
# 3         NaN  RWH  NHS England East Of England
# 4         NaN  RDE  NHS England East Of England
#
#                                              England  1450686  51237   887141  \
# 0                                                NaN      NaN    NaN      NaN
# 1        Bedfordshire Hospitals NHS Foundation Trust  17026.0    0.0   9599.0
# 2  Cambridge University Hospitals NHS Foundation ...  11282.0    0.0   6535.0
# 3             East And North Hertfordshire NHS Trust   9225.0    0.0   8769.0
# 4  East Suffolk And North Essex NHS Foundation Trust  13117.0    0.0  15563.0
#
#    2389064  883691  48929  ...  0.967936  404354  1366   4569  410289  140840  \
# 0      NaN     NaN    NaN  ...       NaN     NaN   NaN    NaN     NaN     NaN
# ...

# %%
df = pd.read_excel(file_path, sheet_name='Provider Level Data',skiprows=14)

df.head()
# Out:
#    Unnamed: 0 Unnamed: 1                    Unnamed: 2  \
# 0         NaN       Code                        Region
# 1         NaN          -                             -
# 2         NaN        NaN                           NaN
# 3         NaN        RC9  NHS England East Of England
# 4         NaN        RGT  NHS England East Of England
#
#                                           Unnamed: 3  \
# 0                                               Name
# 1                                            England
# 2                                                NaN
# 3        Bedfordshire Hospitals NHS Foundation Trust
# 4  Cambridge University Hospitals NHS Foundation ...
#
#                   A&E attendances                             Unnamed: 5  \
# 0  Type 1 Departments - Major A&E  Type 2 Departments - Single Specialty
# 1                         1450686                                  51237
# 2                             NaN                                    NaN
# ...

# %%
import pandas as pd

file_path ="/Users/winifred/Documents/NHS-Wait-Time-Analysis/Data/Raw/ae_wait_times_03_2025.xls"

xls = pd.ExcelFile(file_path)

xls.sheet_names
# Out:
# ['System Level Data',
#  'System Mapping',
#  'Provider Level Data',
#  'Non-Booked Data',
#  'Booked Appointments Data',
#  'Acute Trust Footprint Data',
#  'Acute Trust Mapping']
