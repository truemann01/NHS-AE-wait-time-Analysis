# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Make plots look nicer
sns.set(style="whitegrid")
# %matplotlib inline

# %%
df = pd.read_csv('/Users/winifred/Documents/NHS-Wait-Time-Analysis/Data/Cleaned/nhs_ae_cleaned.csv')

df.head()
# Out:
#   provider_code                        region  \
# 0           RC9  NHS England East Of England
# 1           RGT  NHS England East Of England
# 2           RWH  NHS England East Of England
# 3           RDE  NHS England East Of England
# 4           RY4  NHS England East Of England
#
#                                           trust_name  type_1_ae_attendances  \
# 0        Bedfordshire Hospitals NHS Foundation Trust                17026.0
# 1  Cambridge University Hospitals NHS Foundation ...                11282.0
# 2             East And North Hertfordshire NHS Trust                 9225.0
# 3  East Suffolk And North Essex NHS Foundation Trust                13117.0
# 4                  Hertfordshire Community NHS Trust                    0.0
#
#    type_2_ae_attendances  type_3_ae_attendances  total_ae_attendances  \
# 0                    0.0                 9599.0               26625.0
# 1                    0.0                 6535.0               17817.0
# ...

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=top_10_type1,
    x='type_1_ae_attendances',
    y='trust_name',
    hue='trust_name',  # Workaround to avoid warning
    palette='Blues_d',
    legend=False
)

plt.title('Top 10 NHS Trusts by Type 1 A&E Attendances (March 2025)', fontsize=14, weight='bold')
plt.xlabel('Type 1 A&E Attendances')
plt.ylabel('NHS Trust')
plt.figtext(
    0.5, -0.05,
    'Figure: NHS Trusts with the highest number of Type 1 A&E attendances, indicating potential pressure points.',
    wrap=True,
    horizontalalignment='center',
    fontsize=10
)

plt.tight_layout()
plt.savefig('/Users/winifred/Documents/NHS-Wait-Time-Analysis/visualisations/top_attendances.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.barplot(
    data=bottom_10_seen,
    x='_seen_4_hours',
    y='trust_name',
    hue='trust_name',  # Temporary workaround for future warning
    palette='Reds_d',
    legend=False
)

plt.title('Bottom 10 NHS Trusts by % Seen Within 4 Hours', fontsize=14, weight='bold')
plt.xlabel('% Seen Within 4 Hours')
plt.ylabel('NHS Trust')
plt.figtext(
    0.5, -0.05,
    'Figure: Trusts with the lowest percentage of A&E patients seen within the target 4-hour window.',
    wrap=True,
    horizontalalignment='center',
    fontsize=10
)

plt.tight_layout()
plt.savefig('/Users/winifred/Documents/NHS-Wait-Time-Analysis/visualisations/worst_wait_times.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(
    data=df,
    x='type_1_ae_attendances',
    y='_seen_4_hours',
    hue='region',
    palette='Set2',
    s=100
)

# Title and axis labels
plt.title('Relationship Between Type 1 A&E Attendances and Wait Time Performance', fontsize=14, weight='bold')
plt.xlabel('Type 1 A&E Attendances')
plt.ylabel('% Seen Within 4 Hours')

# Optional caption as a textbox
plt.figtext(
    0.5, -0.05,
    'Figure: NHS Trusts by Region showing correlation between Type 1 attendances and percentage seen within 4 hours.',
    wrap=True,
    horizontalalignment='center',
    fontsize=10
)

plt.grid(True)
plt.tight_layout()

# Save to file
plt.savefig('/Users/winifred/Documents/NHS-Wait-Time-Analysis/visualisations/scatter_performance.png', dpi=300, bbox_inches='tight')

# Display the plot
plt.show()
